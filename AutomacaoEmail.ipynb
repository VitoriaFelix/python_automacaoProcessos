# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1

pyautogui.hotkey('ctrl', 't')
link = 'https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing'
pyperclip.copy(link)
pyautogui.hotkey('ctrl','v')
pyautogui.press('enter')
time.sleep(5)
pyautogui.click(x=420,y=375, clicks=2)

time.sleep(2)
pyautogui.click(x=515,y=425)
pyautogui.click(x=1673,y=248)
pyautogui.click(x=1463,y=731)
time.sleep(3)

# %% [markdown]
# ### Ler o arquivo baixado para pegar os indicadores
#
# - Faturamento
# - Quantidade de Produtos

# %%
import pandas as pd

tabela = pd.read_excel(r"C:\Users\Home\Downloads\Vendas - Dez.xlsx")
faturamento = tabela["Valor Final"].sum()
quantidade = tabela["Quantidade"].sum()
display(tabela)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %% [markdown]
# ### Vamos agora enviar um e-mail pelo gmail

# %%
pyautogui.hotkey('ctrl', 't') 
link = "https://mail.google.com/"
pyperclip.copy(link)
pyautogui.hotkey('ctrl','v')
pyautogui.press('enter')

time.sleep(5) 
pyautogui.click(x = 131, y =274) 

pyautogui.write("seuemail@hotmail.com") 
pyautogui.press("tab") 
pyautogui.press("tab") 


assunto =  "Relatório de Vendas"
pyperclip.copy(assunto)
pyautogui.hotkey('ctrl','v')

pyautogui.press("tab") 

texto = f"""
Prezados, bom dia

O faturamento foi de R${faturamento:,.2f}
A quantidade de produtos foi de {quantidade:,}

Att,
Vitoria Lima
"""
pyautogui.write(texto)
pyautogui.hotkey('ctrl','enter')

# %% [markdown]
# #### código para descobrir qual a posição de um item que queira clicar

# %% [raw]
# import time
# time.sleep(5)
# pyautogui.position()
